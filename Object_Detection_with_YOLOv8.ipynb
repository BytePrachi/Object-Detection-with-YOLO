# %%
# For generating the dataset go to"https://app.roboflow.com/prachi-jain-8kpmw/object_detection_using_yolov8/generate/preprocessing"

# %% [markdown]
# # **Installing dependies**

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 179MB/s]

# %%
from IPython import display
display.clear_output()

# Public API for display tools in IPython
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Object-Detection-with-YOLOv8
# Out:
# /content/drive/MyDrive/Object-Detection-with-YOLOv8

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %% [markdown]
# # **Modes:**
# train, val, predict
#
# # **Tasks:**
# detect,segment,classify
#
# #**Data:**
# Format can be differ for task type,Supports data.yaml, data_folder,data_name

# %%
# !pip install --upgrade ultralytics roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 131MB/s]

# %% [markdown]
# ### **Custom Training Part**

# %%
# %cd /content/drive/MyDrive/Object-Detection-with-YOLOv8
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Object-Detection-with-YOLOv8/data.yaml epochs=25 save=True
# Out:
# /content/drive/MyDrive/Object-Detection-with-YOLOv8
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.
# ...
# 100% 6.23M/6.23M [00:00<00:00, 54.8MB/s]
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					    PR_curve.png	train_batch586.jpg
# confusion_matrix_normalized.png			    R_curve.png		train_batch587.jpg
# confusion_matrix.png				    results.csv		val_batch0_labels.jpg
# events.out.tfevents.1699495942.f29c73a0870c.6083.0  results.png		val_batch0_pred.jpg
# F1_curve.png					    train_batch0.jpg	val_batch1_labels.jpg
# labels_correlogram.jpg				    train_batch1.jpg	val_batch1_pred.jpg
# labels.jpg					    train_batch2.jpg	weights
# P_curve.png					    train_batch585.jpg

# %%
Image(filename='runs/detect/train/results.png', width=800)

# %%
Image(filename='runs/detect/train/val_batch0_labels.jpg', width=700)

# %% [markdown]
# # **Using validation mode**

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=/content/drive/MyDrive/Object-Detection-with-YOLOv8/data.yaml
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Object-Detection-with-YOLOv8/valid/labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100% 40/40 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:15<00:00,  5.19s/it]
#                    all         40         83      0.633      0.448      0.559      0.351
#          auto-rickshaw         40         19      0.999      0.526       0.69      0.376
#                   bike         40          6      0.512      0.167      0.191     0.0743
#                    bus         40         12       0.83      0.817      0.888      0.538
#                    car         40         23       0.79      0.391       0.52      0.275
#                  tempo         40          4          0          0     0.0173     0.0086
# ...

# %% [markdown]
# # **Inferencing or Predicting**

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Object-Detection-with-YOLOv8/test/images
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/13 /content/drive/MyDrive/Object-Detection-with-YOLOv8/test/images/20210427_05_35_43_000_ovRKxW0QbBVfwN9RW4teROP1YgG3_F_4160_3120_jpg.rf.ce640d930f7d1f41f394c3fa69a75b11.jpg: 640x640 (no detections), 254.2ms
# image 2/13 /content/drive/MyDrive/Object-Detection-with-YOLOv8/test/images/20210509_15_20_08_000_RMkLr8rWJDMBfnDv6WRtqfoMLT83_F_3264_2448_jpg.rf.310078b17458552dc527484895250724.jpg: 640x640 1 bike, 2 cars, 244.0ms
# image 3/13 /content/drive/MyDrive/Object-Detection-with-YOLOv8/test/images/20210514_18_54_26_000_uA7x1XuBPngcHFRu7KambGvmgt62_F_5632_4224_jpg.rf.ead4872de6cd2fa57782929bd5950fe2.jpg: 640x640 1 bus, 1 car, 1 truck, 232.0ms
# ...
